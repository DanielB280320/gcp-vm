# %%
import pandas as pd
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types
from pyspark.sql.functions import col

# %%
pyspark.__file__
# Out:
# '/home/daniel/anaconda3/lib/python3.13/site-packages/pyspark/__init__.py'

# %%
spark = SparkSession.builder \
        .master('local[*]') \
        .appName('taxi_data_consolidated') \
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/09 04:51:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df_green = \
    spark.read \
    .option('header', 'true') \
    .option('recursiveFileLookup', 'true') \
    .parquet('/home/daniel/notebooks/taxi_data_pq/green/')

# %%
df_yellow = \
    spark.read \
    .option('header', 'true') \
    .option('recursiveFileLookup', 'true') \
    .parquet('/home/daniel/notebooks/taxi_data_pq/yellow/')

# %%
# normalizing green columns: 
df_green = df_green \
    .withColumnRenamed('lpep_pickup_datetime', 'pickup_datetime') \
    .withColumnRenamed('lpep_dropoff_datetime', 'dropoff_datetime') \
    .withColumn('taxi_type', F.lit('green')) \
    .select(
        'VendorID', 
        'pickup_datetime', 
        'dropoff_datetime', 
        'store_and_fwd_flag',
        'RatecodeID',
        'PULocationID',
        'DOLocationID',
        'passenger_count',
        'trip_distance',
        'fare_amount',
        'extra',
        'mta_tax',
        'tip_amount',
        'tolls_amount',
        'ehail_fee',
        'improvement_surcharge',
        'total_amount',
        'payment_type',
        'trip_type',
        'congestion_surcharge',
        'taxi_type'
    )

# %%
# normalizing yellow columns: 
df_yellow = df_yellow \
    .withColumnRenamed('tpep_pickup_datetime', 'pickup_datetime') \
    .withColumnRenamed('tpep_dropoff_datetime', 'dropoff_datetime') \
    .withColumn('taxi_type', F.lit('yellow')) \
    .select(
        'VendorID', 
        'pickup_datetime', 
        'dropoff_datetime', 
        'passenger_count',
        'trip_distance',
        'RatecodeID',
        'store_and_fwd_flag',
        'PULocationID',
        'DOLocationID',
        'payment_type',
        'fare_amount',
        'extra',
        'mta_tax',
        'tip_amount',
        'tolls_amount',
        'improvement_surcharge',
        'total_amount',
        'congestion_surcharge', 
        'taxi_type'
    )

# %%
commons_cols = []

for col_green in df_green.columns:
    for col_yellow in df_yellow.columns:
        
        if col_green == col_yellow: 
            commons_cols.append(col_green)
        
        else: 
            None

# %%
commons_cols
# Out:
# ['VendorID',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'store_and_fwd_flag',
#  'RatecodeID',
#  'PULocationID',
#  'DOLocationID',
#  'passenger_count',
#  'trip_distance',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'payment_type',
#  'congestion_surcharge',
#  'taxi_type']

# %%
df_green = df_green.select(commons_cols)

# %%
df_green.select(F.count('*')).show()
# Out:
# [Stage 2:=======================================>                   (4 + 2) / 6]
# +--------+
# |count(1)|
# +--------+
# | 8348567|
# +--------+

# %%
df_yellow = df_yellow.select(commons_cols)

# %%
df_yellow.select(F.count('*')).show()
# Out:
# [Stage 5:==================================================>      (30 + 4) / 34]
# +---------+
# | count(1)|
# +---------+
# |124048218|
# +---------+

# %%
yellow_green_dataset_unioned = df_yellow.union(df_green)

# %%
yellow_green_dataset_unioned.select(F.count('*')).show()
# Out:
# [Stage 8:===============================================>         (33 + 5) / 40]
# +---------+
# | count(1)|
# +---------+
# |132396785|
# +---------+

# %%
df_yellow.createOrReplaceTempView('df_yellow_groupby')

# %%
df_yellow_groupby = spark.sql(
    """
    SELECT 
        PULocationID AS pickup_zone_ID, 
        DATE_TRUNC('MONTH', pickup_datetime) AS revenue_month,

        SUM(total_amount) AS Total_revenue_monthly,
        COUNT(PULocationID) AS Total_trips_monthly

    FROM 
        df_yellow_groupby
    GROUP BY 
        PULocationID,
        DATE_TRUNC('MONTH', pickup_datetime)
    ORDER BY 
        Total_revenue_monthly DESC NULLS LAST
    """
)

# %%
df_yellow_groupby.show()
# Out:
# [Stage 11:======================================================> (33 + 1) / 34]
# +--------------+-------------------+---------------------+-------------------+
# |pickup_zone_ID|      revenue_month|Total_revenue_monthly|Total_trips_monthly|
# +--------------+-------------------+---------------------+-------------------+
# |           132|2019-05-01 00:00:00| 1.4015883699987967E7|             246361|
# |           132|2019-10-01 00:00:00| 1.3570893849986957E7|             248324|
# |           132|2019-06-01 00:00:00| 1.3383431569991782E7|             235445|
# |           132|2019-09-01 00:00:00| 1.3221411419987496E7|             241466|
# |           132|2019-04-01 00:00:00| 1.3190374339988995E7|             230420|
# |           132|2019-03-01 00:00:00| 1.3179773499980763E7|             226740|
# |           132|2019-07-01 00:00:00|  1.303985379999401E7|             237736|
# |           132|2019-08-01 00:00:00| 1.2976801389993954E7|             240804|
# |           132|2019-12-01 00:00:00|  1.239407688998855E7|             229793|
# |           132|2019-11-01 00:00:00| 1.1969940419992719E7|             221053|
# |           132|2020-01-01 00:00:00| 1.1342125689989874E7|             214217|
# |           132|2019-01-01 00:00:00| 1.1161023109988138E7|             196600|
# |           132|2019-02-01 00:00:00| 1.0268865589991301E7|             174784|
# |           132|2020-02-01 00:00:00|     9911486.97999209|             188491|
# |           138|2019-03-01 00:00:00|    9145457.989997435|             212358|
# |           138|2019-05-01 00:00:00|    8835530.689993827|             206433|
# |           138|2019-02-01 00:00:00|    8503547.759999508|             178439|
# |           138|2019-04-01 00:00:00|    8288362.189994858|             194646|
# |           138|2019-06-01 00:00:00|    8109036.929997648|             191283|
# |           138|2019-10-01 00:00:00|   7619776.6999957245|             175538|
# +--------------+-------------------+---------------------+-------------------+
# only showing top 20 rows

# %%
df_yellow_groupby = \
    df_yellow \
    .withColumn('revenue_month',F.date_trunc('month', df_yellow.pickup_datetime)) \
    .select(
        #Grouping columns: 
        df_yellow.PULocationID.alias('pickup_zone_ID'), 
        F.col('revenue_month'), 

        #Aggregations columns: 
        df_yellow.total_amount, 
        df_yellow.PULocationID
    ) \
    .filter(F.col('revenue_month') >= '2019-01-01 00:00:00') \
    .groupBy(
        F.col('pickup_zone_ID'), 
        F.col('revenue_month')
    ) \
    .agg(
        F.sum(df_yellow.total_amount).alias('Total_revenue_monthly_yellow'), 
        F.count(df_yellow.PULocationID).alias('Total_trips_monthly_yellow')
    ) \
    .orderBy(
        F.desc(F.col('Total_revenue_monthly_yellow'))
    )

# %%
df_yellow_groupby.show()
# Out:
# [Stage 14:======================================================> (33 + 1) / 34]
# +--------------+-------------------+----------------------------+--------------------------+
# |pickup_zone_ID|      revenue_month|Total_revenue_monthly_yellow|Total_trips_monthly_yellow|
# +--------------+-------------------+----------------------------+--------------------------+
# |           132|2019-05-01 00:00:00|        1.4015883699987967E7|                    246361|
# |           132|2019-10-01 00:00:00|        1.3570893849986957E7|                    248324|
# |           132|2019-06-01 00:00:00|        1.3383431569991782E7|                    235445|
# |           132|2019-09-01 00:00:00|        1.3221411419987496E7|                    241466|
# |           132|2019-04-01 00:00:00|        1.3190374339988995E7|                    230420|
# |           132|2019-03-01 00:00:00|        1.3179773499980763E7|                    226740|
# |           132|2019-07-01 00:00:00|         1.303985379999401E7|                    237736|
# |           132|2019-08-01 00:00:00|        1.2976801389993954E7|                    240804|
# |           132|2019-12-01 00:00:00|         1.239407688998855E7|                    229793|
# |           132|2019-11-01 00:00:00|        1.1969940419992719E7|                    221053|
# |           132|2020-01-01 00:00:00|        1.1342125689989874E7|                    214217|
# |           132|2019-01-01 00:00:00|        1.1161023109988138E7|                    196600|
# |           132|2019-02-01 00:00:00|        1.0268865589991301E7|                    174784|
# |           132|2020-02-01 00:00:00|            9911486.97999209|                    188491|
# |           138|2019-03-01 00:00:00|           9145457.989997435|                    212358|
# |           138|2019-05-01 00:00:00|           8835530.689993827|                    206433|
# |           138|2019-02-01 00:00:00|           8503547.759999508|                    178439|
# |           138|2019-04-01 00:00:00|           8288362.189994858|                    194646|
# |           138|2019-06-01 00:00:00|           8109036.929997648|                    191283|
# |           138|2019-10-01 00:00:00|          7619776.6999957245|                    175538|
# +--------------+-------------------+----------------------------+--------------------------+
# only showing top 20 rows

# %%
df_yellow_groupby \
    .repartition(20) \
    .write.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/yellow', 
                   mode= 'overwrite'
                  )

# %%
df_green_groupby = \
    df_green \
    .withColumn('revenue_month',F.date_trunc('month', df_green.pickup_datetime)) \
    .select(
        #Grouping columns: 
        df_green.PULocationID.alias('pickup_zone_ID'), 
        F.col('revenue_month'), 

        #Aggregations columns: 
        df_green.total_amount, 
        df_green.PULocationID
    ) \
    .filter(F.col('revenue_month') >= '2019-01-01 00:00:00') \
    .groupBy(
        F.col('pickup_zone_ID'), 
        F.col('revenue_month')
    ) \
    .agg(
        F.sum(df_green.total_amount).alias('Total_revenue_monthly_green'), 
        F.count(df_green.PULocationID).alias('Total_trips_monthly_green')
    ) \
    .orderBy(
        F.desc(F.col('Total_revenue_monthly_green'))
    )

# %%
df_green_groupby.show(5)
# Out:
# [Stage 29:======================================>                   (4 + 2) / 6]
# +--------------+-------------------+---------------------------+-------------------------+
# |pickup_zone_ID|      revenue_month|Total_revenue_monthly_green|Total_trips_monthly_green|
# +--------------+-------------------+---------------------------+-------------------------+
# |            74|2019-03-01 00:00:00|          574765.1499999098|                    42049|
# |            74|2019-05-01 00:00:00|          567312.4299998907|                    40274|
# |            74|2019-06-01 00:00:00|          561003.1399998823|                    39178|
# |            74|2019-07-01 00:00:00|          553773.2699998681|                    39201|
# |            74|2019-09-01 00:00:00|          553324.1199998844|                    37358|
# +--------------+-------------------+---------------------------+-------------------------+
# only showing top 5 rows

# %%
df_green_groupby \
    .repartition(20) \
    .write.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/green', 
                   mode= 'overwrite'
                  )

# %%
# Using materialized results: 
df_green_groupby_imported = \
    spark.read.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/green')

df_yellow_groupby_imported = \
    spark.read.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/yellow')

# %%
df_joined = \
    df_green_groupby_imported \
    .join(
        df_yellow_groupby_imported, 
        on= ['pickup_zone_ID', 'revenue_month'], 
        how= 'outer'
    ) \
    .orderBy(
        F.asc(F.col('revenue_month'))
    )

# %%
df_joined.show(10)
# Out:
# +--------------+-------------------+---------------------------+-------------------------+----------------------------+--------------------------+
# |pickup_zone_ID|      revenue_month|Total_revenue_monthly_green|Total_trips_monthly_green|Total_revenue_monthly_yellow|Total_trips_monthly_yellow|
# +--------------+-------------------+---------------------------+-------------------------+----------------------------+--------------------------+
# |             6|2019-01-01 00:00:00|                     631.54|                       15|          1259.6599999999999|                        33|
# |            11|2019-01-01 00:00:00|         10491.629999999985|                      439|          3890.6799999999976|                       141|
# |             1|2019-01-01 00:00:00|                     745.08|                        8|          41381.449999999924|                       446|
# |             4|2019-01-01 00:00:00|         59.370000000000005|                        3|           197924.5000000129|                     13954|
# |             5|2019-01-01 00:00:00|         253.45999999999998|                        4|          440.64000000000004|                         5|
# |             2|2019-01-01 00:00:00|                       NULL|                     NULL|          462.57000000000005|                        10|
# |             3|2019-01-01 00:00:00|         17223.329999999864|                      676|           5947.720000000001|                       175|
# |             7|2019-01-01 00:00:00|         301454.68999989115|                    26038|          147873.37000001073|                     11303|
# |             8|2019-01-01 00:00:00|         122.77000000000001|                        5|          2671.5699999999993|                        66|
# |             9|2019-01-01 00:00:00|          7921.380000000022|                      388|           2933.519999999997|                       132|
# +--------------+-------------------+---------------------------+-------------------------+----------------------------+--------------------------+
# only showing top 10 rows

# %%
df_joined \
    .write.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/total', 
                   mode= 'overwrite'
                  )

# %%
df_total = \
    spark.read.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/total')

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv

# %%
df_zones = \
    spark.read \
    .option('header','true') \
    .option('inferschema', 'true') \
    .csv('/home/daniel/notebooks/taxi_zone_lookup.csv')

# %%
df_zones \
    .write.parquet('/home/daniel/notebooks/taxi_zone_lookup.parquet', 
                  mode= 'overwrite')

# %%
df_zones = \
    spark.read \
    .option('header','true') \
    .option('inferschema', 'true') \
    .parquet('/home/daniel/notebooks/taxi_zone_lookup.parquet')

# %%
df_zones.show(5)
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 5 rows

# %%
df_enriched = \
    df_total \
        .join(
            df_zones,
            df_total.pickup_zone_ID == df_zones.LocationID,
            how= 'left'
        )

# %%
df_enriched = \
    df_enriched.select(
        'pickup_zone_ID',
        'revenue_month',
        'Total_revenue_monthly_green',
        'Total_trips_monthly_green',
        'Total_revenue_monthly_yellow',
        'Total_trips_monthly_yellow',
        'Borough',
        'Zone',
        'service_zone'
    )

# %%
df_enriched \
    .write.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/enriched', 
                   mode= 'overwrite')

# %% [markdown]
# ## Resilient distribuited datasets (RDDs):

# %%
#df_green before grouping to the see how it was done before when using RDDs
df_green.rdd
# Out:
# MapPartitionsRDD[214] at javaToPython at NativeMethodAccessorImpl.java:0

# %%
rdd = \
    df_green \
    .select(
        df_green.PULocationID, 
        df_green.pickup_datetime,
        df_green.total_amount,
    ) \
    .rdd

# %%
from datetime import datetime

# %%
start = datetime(year=2019, month=1, day=1)

# %%
def filter_outliers(row):
    return row.pickup_datetime >= start

# %%
rows = rdd.take(10)
row = rows[0]

# %%
def prepare_for_grouping(row):
    date = row.pickup_datetime.replace(minute= 0, second= 0, microsecond= 0)
    zone = row.PULocationID
    #composite key
    key = (date, zone)
        
    amount = row.total_amount
    count = 1
    #composite value
    value = (amount, count)

    return (key, value)

# %%
def calculate_revenue(left_value, right_value):
    left_amount, left_count = left_value
    right_amount, right_count = right_value

    output_amount = left_amount + right_amount
    output_count = left_count + right_count

    return (output_amount, output_count)

# %%
from collections import namedtuple

# %%
revenue_row = namedtuple('revenue_row', ['date', 'zone', 'revenue', 'count'])

# %%
def unwrap(row):
    return revenue_row(
        date = row[0][0], 
        zone = row[0][1], 
        revenue = row[1][0], 
        count = row[1][1]

    )

# %%
schema_rrd = types.StructType([
    types.StructField('date', types.TimestampType(), True), 
    types.StructField('zone', types.IntegerType(), True), 
    types.StructField('revenue', types.DoubleType(), True), 
    types.StructField('count', types.IntegerType(), True)
])

# %%
df_results_rrd = \
    rdd \
        .filter(filter_outliers) \
        .map(prepare_for_grouping) \
        .reduceByKey(calculate_revenue) \
        .map(unwrap) \
        .toDF(schema_rrd)

# %%
df_results_rrd.show(5)
# Out:
# [Stage 170:>                                                        (0 + 1) / 1]
# +-------------------+----+------------------+-----+
# |               date|zone|           revenue|count|
# +-------------------+----+------------------+-----+
# |2019-01-30 00:00:00|  82| 295.2600000000001|   28|
# |2019-01-19 23:00:00|  41| 613.0499999999998|   48|
# |2019-01-09 19:00:00| 260| 441.3900000000002|   37|
# |2019-01-28 10:00:00| 179|             76.66|    8|
# |2019-01-03 11:00:00|  42|454.51000000000016|   36|
# +-------------------+----+------------------+-----+
# only showing top 5 rows
# Traceback (most recent call last):
#   File "/home/daniel/spark/spark-4.1.1-bin-hadoop3/python/lib/pyspark.zip/pyspark/daemon.py", line 233, in manager
#     code = worker(sock, authenticated)
#   File "/home/daniel/spark/spark-4.1.1-bin-hadoop3/python/lib/pyspark.zip/pyspark/daemon.py", line 87, in worker
#     outfile.flush()
#     ~~~~~~~~~~~~~^^
# BrokenPipeError: [Errno 32] Broken pipe

# %%
df_results_rrd \
    .write.parquet('/home/daniel/notebooks/taxi_data_reporting/revenue/rdd/', 
                   mode= 'overwrite')

# %%
# !tree -lh taxi_data_reporting
# Out:
# [4.0K]  taxi_data_reporting
# ├── [4.0K]  revenue
# │   ├── [4.0K]  enriched
# │   │   ├── [   0]  _SUCCESS
# │   │   └── [171K]  part-00000-5354a176-96d8-48b6-9d1a-db434ad27ffa-c000.snappy.parquet
# │   ├── [4.0K]  green
# │   │   ├── [   0]  _SUCCESS
# │   │   ├── [7.5K]  part-00000-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.3K]  part-00001-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00002-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.3K]  part-00003-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.3K]  part-00004-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00005-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00006-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00007-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.2K]  part-00008-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.3K]  part-00009-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00010-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.3K]  part-00011-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00012-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00013-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.6K]  part-00014-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.3K]  part-00015-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.5K]  part-00016-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.4K]  part-00017-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   ├── [7.3K]  part-00018-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   │   └── [7.3K]  part-00019-7526db81-175d-4bb5-826a-d616c831d4c8-c000.snappy.parquet
# │   ├── [4.0K]  rdd
# │   │   ├── [   0]  _SUCCESS
# │   │   ├── [1.8M]  part-00000-d89e972a-34c1-4f57-93bd-5dbc55bd3d8a-c000.snappy.parquet
# │   │   ├── [1.8M]  part-00001-d89e972a-34c1-4f57-93bd-5dbc55bd3d8a-c000.snappy.parquet
# │   │   ├── [1.8M]  part-00002-d89e972a-34c1-4f57-93bd-5dbc55bd3d8a-c000.snappy.parquet
# │   │   ├── [1.8M]  part-00003-d89e972a-34c1-4f57-93bd-5dbc55bd3d8a-c000.snappy.parquet
# │   │   ├── [1.8M]  part-00004-d89e972a-34c1-4f57-93bd-5dbc55bd3d8a-c000.snappy.parquet
# │   │   └── [1.8M]  part-00005-d89e972a-34c1-4f57-93bd-5dbc55bd3d8a-c000.snappy.parquet
# │   ├── [4.0K]  total
# │   │   ├── [   0]  _SUCCESS
# │   │   └── [162K]  part-00000-e3b17693-2566-4b75-921e-12a9450856d7-c000.snappy.parquet
# │   └── [4.0K]  yellow
# │       ├── [   0]  _SUCCESS
# │       ├── [8.1K]  part-00000-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [7.8K]  part-00001-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00002-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [7.8K]  part-00003-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00004-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00005-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.0K]  part-00006-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00007-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00008-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00009-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00010-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00011-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.2K]  part-00012-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [7.8K]  part-00013-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00014-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.1K]  part-00015-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.0K]  part-00016-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.2K]  part-00017-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       ├── [8.2K]  part-00018-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# │       └── [7.8K]  part-00019-fa4179dd-23b2-4b58-98af-16b388710ffa-c000.snappy.parquet
# └── [4.0K]  taxi_data_aggregated.parquet
#     ├── [   0]  _SUCCESS
#     └── [865K]  part-00000-2c9d3211-fc9c-4c99-bd06-b40e1bb951a5-c000.snappy.parquet
#
# 7 directories, 55 files
