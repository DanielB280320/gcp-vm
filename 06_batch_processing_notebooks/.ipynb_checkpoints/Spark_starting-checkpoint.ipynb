# %% [markdown]
# ## Starting with spark
#
# - Reading csv files
# - Partitions
# - Exporting data to parquet
# - Spark master UI

# %%
import pandas as pd
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
        .master("local[*]") \
        .appName('test') \
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/06 04:00:20 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhvhv/fhvhv_tripdata_2021-01.csv.gz
# Out:
# --2026-03-06 04:08:34--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhvhv/fhvhv_tripdata_2021-01.csv.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !gunzip fhvhv_tripdata_2021-01.csv.gz

# %%
# !wc -l fhvhv_tripdata_2021-01.csv
# Out:
# 11908469 fhvhv_tripdata_2021-01.csv

# %%
df = spark.read \
    .option('header', 'true') \
    .csv('fhvhv_tripdata_2021-01.csv')

# %%
df.schema
# Out:
# StructType([StructField('hvfhs_license_num', StringType(), True), StructField('dispatching_base_num', StringType(), True), StructField('pickup_datetime', StringType(), True), StructField('dropoff_datetime', StringType(), True), StructField('PULocationID', StringType(), True), StructField('DOLocationID', StringType(), True), StructField('SR_Flag', StringType(), True)])

# %%
# !head -n 101 fhvhv_tripdata_2021-01.csv > head.csv

# %%
# !wc -l head.csv
# Out:
# 101 head.csv

# %%
df_pandas = pd.read_csv('head.csv')

# %%
df_pandas.dtypes
# Out:
# hvfhs_license_num        object
# dispatching_base_num     object
# pickup_datetime          object
# dropoff_datetime         object
# PULocationID              int64
# DOLocationID              int64
# SR_Flag                 float64
# dtype: object

# %%
spark.createDataFrame(df_pandas).schema # Long is less memory efficiente format
# Out:
# StructType([StructField('hvfhs_license_num', StringType(), True), StructField('dispatching_base_num', StringType(), True), StructField('pickup_datetime', StringType(), True), StructField('dropoff_datetime', StringType(), True), StructField('PULocationID', LongType(), True), StructField('DOLocationID', LongType(), True), StructField('SR_Flag', DoubleType(), True)])

# %%
from pyspark.sql import types

# %%
schema = types.StructType([
    types.StructField('hvfhs_license_num', types.StringType(), True), 
    types.StructField('dispatching_base_num', types.StringType(), True), 
    types.StructField('pickup_datetime', types.TimestampType(), True), 
    types.StructField('dropoff_datetime', types.TimestampType(), True), 
    types.StructField('PULocationID', types.IntegerType(), True), 
    types.StructField('DOLocationID', types.IntegerType(), True), 
    types.StructField('SR_Flag', types.StringType(), True)
])

# %%
df = spark.read \
    .option('header', 'true') \
    .schema(schema) \
    .csv('fhvhv_tripdata_2021-01.csv')

# %%
df.schema
# Out:
# StructType([StructField('hvfhs_license_num', StringType(), True), StructField('dispatching_base_num', StringType(), True), StructField('pickup_datetime', TimestampType(), True), StructField('dropoff_datetime', TimestampType(), True), StructField('PULocationID', IntegerType(), True), StructField('DOLocationID', IntegerType(), True), StructField('SR_Flag', StringType(), True)])

# %%
df = df.repartition(24)  #repartition is a lazy command

# %%
df.write.parquet('fhvhv_2021_01')

# %% [markdown]
# ## Spark Dataframes
#
# - Actions vs transformatios
# - Partitions
# - Functions and UDFs

# %%
df = spark.read.parquet('fhvhv_2021_01')

# %%
df.printSchema()
# Out:
# root
#  |-- hvfhs_license_num: string (nullable = true)
#  |-- dispatching_base_num: string (nullable = true)
#  |-- pickup_datetime: timestamp (nullable = true)
#  |-- dropoff_datetime: timestamp (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- SR_Flag: string (nullable = true)

# %%
df.columns
# Out:
# ['hvfhs_license_num',
#  'dispatching_base_num',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'PULocationID',
#  'DOLocationID',
#  'SR_Flag']

# %%
df.select('pickup_datetime','dropoff_datetime', 'PULocationID','DOLocationID') \
  .filter(df.hvfhs_license_num == 'HV0003') \
  .show()
# Out:
# +-------------------+-------------------+------------+------------+
# |    pickup_datetime|   dropoff_datetime|PULocationID|DOLocationID|
# +-------------------+-------------------+------------+------------+
# |2021-01-05 22:14:07|2021-01-05 22:32:28|         189|         107|
# |2021-01-02 17:59:55|2021-01-02 18:10:39|          88|         137|
# |2021-01-02 23:57:54|2021-01-03 00:15:48|         238|         224|
# |2021-01-06 15:53:13|2021-01-06 16:07:07|         169|         208|
# |2021-01-07 07:35:24|2021-01-07 07:55:49|          75|          88|
# |2021-01-07 08:45:12|2021-01-07 08:51:17|         210|         210|
# |2021-01-02 15:44:26|2021-01-02 16:10:50|         243|          69|
# |2021-01-04 16:50:28|2021-01-04 16:57:43|         250|         213|
# |2021-01-03 10:30:34|2021-01-03 10:44:53|          87|          79|
# |2021-01-03 22:05:20|2021-01-03 22:27:55|          68|         181|
# |2021-01-04 08:01:02|2021-01-04 08:33:27|          95|         236|
# ...

# %% [markdown]
# ### Actions (eager) vs Transformations (lazy):
#
# <b> Transformations: </b> not executed inmediately
# - .select()
# - .filter()
# - .joins()
# - .groupby()
#
# <b> Actions: </b> executed inmediately
# - .show()
# - .take()
# - .head()
# - .write()

# %% [markdown]
# ### SparkSQL and SQL Notation:
#
# The differences between using Sparksql and sql notation is that spark is more flexible for doing complex transformations and also let us define UDFs

# %%
from pyspark.sql import functions as F # Collections of built in functions in spark

# %%
df \
    .withColumn('pickup_date', F.to_date(df.pickup_datetime)) \
    .withColumn('dropoff_date', F.to_date(df.dropoff_datetime)) \
    .select('pickup_date', 'dropoff_date', df.PULocationID, df.DOLocationID) \
    .show()
# Out:
# +-----------+------------+------------+------------+
# |pickup_date|dropoff_date|PULocationID|DOLocationID|
# +-----------+------------+------------+------------+
# | 2021-01-03|  2021-01-03|         255|          34|
# | 2021-01-05|  2021-01-05|         189|         107|
# | 2021-01-02|  2021-01-02|          88|         137|
# | 2021-01-02|  2021-01-03|         238|         224|
# | 2021-01-06|  2021-01-06|         169|         208|
# | 2021-01-07|  2021-01-07|          75|          88|
# | 2021-01-07|  2021-01-07|         210|         210|
# | 2021-01-02|  2021-01-02|         243|          69|
# | 2021-01-04|  2021-01-04|         250|         213|
# | 2021-01-03|  2021-01-03|          87|          79|
# | 2021-01-03|  2021-01-03|          68|         181|
# | 2021-01-04|  2021-01-04|          95|         236|
# | 2021-01-02|  2021-01-02|         262|         236|
# | 2021-01-04|  2021-01-04|         225|         233|
# | 2021-01-06|  2021-01-06|         237|          83|
# ...

# %%
# UDFs: 

def custom_functions(base_num):
    num = int(base_num[1:])
    if num % 7 == 0:
        return f's/{num:03x}'
    elif num % 3 == 0:
        return f'a/{num:03x}'
    else: 
        return f'e/{num:03x}'

# %%
custom_functions('B02253')
# Out:
# 'a/8cd'

# %%
#Defining a UDF: 
custom_function_udf = F.udf(custom_functions, returnType= types.StringType())

# %%
df \
    .withColumn('pickup_date', F.to_date(df.pickup_datetime)) \
    .withColumn('dropoff_date', F.to_date(df.dropoff_datetime)) \
    .withColumn('baseid', custom_function_udf(df.dispatching_base_num)) \
    .select('pickup_date', 'dropoff_date', 'baseid', df.PULocationID, df.DOLocationID) \
    .show()
# Out:
# [Stage 32:>                                                         (0 + 1) / 1]
# +-----------+------------+------+------------+------------+
# |pickup_date|dropoff_date|baseid|PULocationID|DOLocationID|
# +-----------+------------+------+------------+------------+
# | 2021-01-03|  2021-01-03| e/9ce|         255|          34|
# | 2021-01-05|  2021-01-05| e/b42|         189|         107|
# | 2021-01-02|  2021-01-02| e/b33|          88|         137|
# | 2021-01-02|  2021-01-03| e/b38|         238|         224|
# | 2021-01-06|  2021-01-06| e/b3b|         169|         208|
# | 2021-01-07|  2021-01-07| e/b33|          75|          88|
# | 2021-01-07|  2021-01-07| e/acc|         210|         210|
# | 2021-01-02|  2021-01-02| e/acc|         243|          69|
# | 2021-01-04|  2021-01-04| e/b35|         250|         213|
# | 2021-01-03|  2021-01-03| s/b3d|          87|          79|
# | 2021-01-03|  2021-01-03| e/a39|          68|         181|
# ...
